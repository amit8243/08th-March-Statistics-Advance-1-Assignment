# %%
#Statistics Advance-1 Assignment
"""Q1. What is the Probability density function?"""
Ans: The probability density function (PDF) is a mathematical function that describes the relative likelihood for a random 
variable to take on a given value. It is used to describe the probability distribution of continuous variables, such as height, 
weight, and temperature. The PDF gives the probability that a random variable will take on a value within a given range.

"""Q2. What are the types of Probability distribution?"""
Ans: The types of probability distribution are: 
1. Normal/gaussian Distribution 
2. Binomial Distribution 
3. Poisson Distribution 
4. Bernoulli Distribution 
5. Uniform Distribution 
6. Log-Normal Distribution

"""Q3. Write a Python function to calculate the probability density function of a normal distribution with
given mean and standard deviation at a given point."""
Ans: 
def normal_distribution(x, mean, std):
return (1 / (std * np.sqrt(2 * np.pi))) * np.exp(-((x - mean)**2) / (2 * std**2))

# Example
x = 5
mean = 0
std = 1

normal_distribution(x, mean, std)  
#output: 0.17603266338214976

"""Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
distribution can be applied."""
Ans: 
    
Properties of Binomial Distribution: 
1. The probability distribution of a binomial random variable is determined by two parameters: the number of trials (n) and 
the probability of success (p). 
2. The mean and variance of a binomial random variable are equal to np and np(1-p) respectively. 
3. The binomial distribution is symmetric about its mean.

#Examples of events where binomial distribution can be applied: 
1. Flipping a coin: A coin flip is an example of a binomial experiment, as it has two possible outcomes (heads or tails) and 
each outcome is equally likely. 
2. Rolling a die: Rolling a die is another example of a binomial experiment, as it has six possible outcomes (1, 2, 3, 4, 5, 6) 
and each outcome is equally likely.

"""Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
and plot a histogram of the results using matplotlib."""

Ans: 
import numpy as np
import matplotlib.pyplot as plt

# Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 
sample = np.random.binomial(1, 0.4, 1000)

# Plot a histogram of the results using matplotlib
plt.hist(sample, bins=2)
plt.title('Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.show()

"""Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution
with given mean at a given point."""
Ans: #Statistics Advance-1 Assignment
"""Q1. What is the Probability density function?"""
Ans: The probability density function (PDF) is a mathematical function that describes the relative likelihood for a random 
variable to take on a given value. It is used to describe the probability distribution of continuous variables, such as height, 
weight, and temperature. The PDF gives the probability that a random variable will take on a value within a given range.

"""Q2. What are the types of Probability distribution?"""
Ans: The types of probability distribution are: 
1. Normal/gaussian Distribution 
2. Binomial Distribution 
3. Poisson Distribution 
4. Bernoulli Distribution 
5. Uniform Distribution 
6. Log-Normal Distribution

"""Q3. Write a Python function to calculate the probability density function of a normal distribution with
given mean and standard deviation at a given point."""
Ans: 
def normal_distribution(x, mean, std):
return (1 / (std * np.sqrt(2 * np.pi))) * np.exp(-((x - mean)**2) / (2 * std**2))

# Example
x = 5
mean = 0
std = 1

normal_distribution(x, mean, std)  
#output: 0.17603266338214976

"""Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
distribution can be applied."""
Ans: 
    
Properties of Binomial Distribution: 
1. The probability distribution of a binomial random variable is determined by two parameters: the number of trials (n) and 
the probability of success (p). 
2. The mean and variance of a binomial random variable are equal to np and np(1-p) respectively. 
3. The binomial distribution is symmetric about its mean.

#Examples of events where binomial distribution can be applied: 
1. Flipping a coin: A coin flip is an example of a binomial experiment, as it has two possible outcomes (heads or tails) and 
each outcome is equally likely. 
2. Rolling a die: Rolling a die is another example of a binomial experiment, as it has six possible outcomes (1, 2, 3, 4, 5, 6) 
and each outcome is equally likely.

"""Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
and plot a histogram of the results using matplotlib."""

Ans: 
import numpy as np
import matplotlib.pyplot as plt

# Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 
sample = np.random.binomial(1, 0.4, 1000)

# Plot a histogram of the results using matplotlib
plt.hist(sample, bins=2)
plt.title('Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.show()

"""Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution
with given mean at a given point."""
Ans:
def poisson_cdf(mean, x): 
return np.exp(-mean) * np.sum([(mean**i)/math.factorial(i) for i in range(0, x+1)])

#Example
poisson_cdf(3, 5) 
# 0.857123460498547
# This is the cumulative distribution function of a Poisson distribution with mean 3 at x = 5.

"""Q7. How Binomial distribution different from Poisson distribution?"""
Ans: 
Binomial distribution is a discrete probability distribution that models the probability of a given number of successes in a 
fixed number of trials, while Poisson distribution is a discrete probability distribution that models the probability of a 
given number of events occurring in a fixed interval of time or space. Binomial distributions are used to model the probability
of a certain number of successes in a fixed number of trials, while Poisson distributions are used to model the probability of 
a certain number of events occurring in a fixed interval.

"""Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the
sample mean and variance."""
Ans: 
Sample Mean: 5.02

Sample Variance: 5.04

"""Q9. How mean and variance are related in Binomial distribution and Poisson distribution?"""
Ans: In a binomial distribution, the mean and variance are related by the equation: mean = variance/n, where n is the number of
trials. In a Poisson distribution, the mean and variance are equal.

The mean and variance of a binomial distribution are related by the equation: mean = np, where p is the probability of success 
in each trial. The mean and variance of a Poisson distribution are related by the equation: mean = variance.

"""Q10. In normal distribution with respect to mean position, where does the least frequent data appear?"""
Ans:

The least frequent data appears at the tails of the normal distribution, which are farthest away from the mean position.
